# %%
model = 'WDN'
# num_layers = [3,5,7,9,11]
lr = [1e-2, 2e-3, 5e-4]
embed_dim = [4,32,128]

# %%
for l in lr:
    for ed in embed_dim:
                # %run main.py --model={model} --epochs=30 --batch_size=16 --lr={l} --embed_dim={ed} --dropout=0.6
# Out:
# --------------- WDN Load Data ---------------
# --------------- WDN Train/Valid Split ---------------
# --------------- INIT WDN ---------------
# --------------- WDN TRAINING ---------------
# wandb: Currently logged in as: tmdals179. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/opt/ml/code/wandb/run-20230418_233327-njwoz09t</code>
# Syncing run <strong><a href='https://wandb.ai/tmdals179/a-family-of-five/runs/njwoz09t' target="_blank">crisp-eon-150</a></strong> to <a href='https://wandb.ai/tmdals179/a-family-of-five' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/tmdals179/a-family-of-five' target="_blank">https://wandb.ai/tmdals179/a-family-of-five</a>
# ...
