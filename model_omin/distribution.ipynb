# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_list = os.listdir('./saved_models/')
files = [pd.read_csv('./saved_models/' + f) for f in file_list]
print(len(files), file_list)
fig, ax = plt.subplots(figsize=(12, 7))
for idx in range(len(files)):
    sns.kdeplot(x='rating', data=files[idx],fill=True)
plt.legend(labels=file_list)
plt.show()
# Out:
# 6 ['20230417_083551_DeepCoNN.csv', 'baseline_catreg_10skf_emb.csv', '20230418_123724_CNN_FM.csv', '20230417_025921_lgbm_2.23116.csv', 'baseline_xgbreg_10skf_3.csv', '20230416_133659_rfr_2.2462.csv']
